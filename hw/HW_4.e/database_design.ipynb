# %% [markdown]
# # Denison CS181/DA210 Homework 4.e - Step 1
#
# Before you turn this notebook in, make sure everything runs as expected. This is a combination of **restarting the kernel** and then **running all cells**.
#
# Make sure you fill in any place that says `# YOUR CODE HERE` or "YOUR ANSWER HERE".

# %% [markdown]
# ---

# %% [markdown]
# ## Part A: Table Design
#
# For this homework, you should think about the data you plan to use in your final project.  You are not committed to the design you develop for the homework, but the goal here is to walk you through the steps of sound database design, to help you along the way with your project.
#
# Note that these kinds of questions rarely have a single right answer, so keep an open mind and try to think carefully about what you are trying to design.

# %% [markdown]
# **Q1:** First, describe the datasets you are working with for the project, using simple English descriptions.  For example, you could describe a dataset related to college course registration, or a team-oriented sports league.

# %% [markdown]
# The datasets I'm working with will contain data about the information about the 50 states and District of Columbia of the U.S. More specifically, the datasets I'm working with contains the data of:
# 1. Educational attainment level of people over 25 of each state or D.C. in 2021
# 2. GDP of each state or D.C. in 2021
# 3. Total personal income of each state or D.C. in 2021

# %% [markdown]
# **Q2:** In database design, we start with identifying the _entities_ that are the collection of _things_ that make up the database.  Even before relationships add other tables, our first goal is to identify the entities and to give a _table name_ for each entity.
#
# For the datasets described in answering the previous question, give a list and description of each of the entities.

# %% [markdown]
# The three entities in my database will be:
# 1. `edu_level` - Educational attainment level of people over 25 of each state or D.C. in 2021
# 2. `gdp` - GDP of each state or D.C. in 2021
# 3. `total_income` - Total personal income of each state or D.C. in 2021

# %% [markdown]
# **Q3:** Check your table names.  List any instances of tables for which:
# - the name of the table is not plural, or
# - the table is defining a relationship between entities (and has a name that is composed of two entities).
#
# If there are no such instances, say so instead.
#
# Note: design is an iterative refinement process, so it's okay to find things that need to be improved (and doesn't necessarily invalidate your answers to the previous questions).

# %% [markdown]
# There aren't any instances like so.

# %% [markdown]
# **Q4:** For each entity table, list the functional dependency that gives the independent variable(s) and a first pass at the dependent variables for the entity.

# %% [markdown]
# For `edu_level`:
# 1. `State or Territory` - Independent variable
# 2. `Population over the age of 25`
# 3. `With a High School Diploma or higher, Population`
# 4. `With a High School Diploma or higher, Percentage`
# 5. `With a Bachelor's Degree or higher, Population`
# 6. `With a Bachelor's Degree or higher, Percentage`
# 7. `With an Advanced Degree, Population`
# 8. `With an Advanced Degree, Percentage`
#
# For `gdp`:
# 1. `State or Territory` - Independent variable
# 2. `GDP in 2021 (in millions of chained 2012 dollars)`
#
# For `total_income`:
# 1. `State or Territory` - Independent variable
# 2. `Total personal income in 2021 (in millions of chained 2012 dollars)`

# %% [markdown]
# **Q5:** Identify any cases where two entity tables have the _same set_ of independent variables on the left-hand side of a functional dependency, and combine into a single table.

# %% [markdown]
# All three tables have the same set of independent variables, so they can all be combined into a single table.

# %% [markdown]
# **Q6:** For each functional dependency, go through the dependent variables and verify whether the variable is dependent on _only a subset_ of the independent variables.
#
# If found, break these out into _different_ functional dependencies.

# %% [markdown]
# No dependent variable in any of the tables is dependent on only a subset of the independent variables.

# %% [markdown]
# **Q7:** Identify the _primary key_ for each table, and state for each whether it is a _singleton_ or _composite_ key.

# %% [markdown]
# The primary key for all three tables is `State or Territory`, and it is a singleton key because the dependent variables are only dependent on that one key.

# %% [markdown]
# ---
#
# ## Part B: Table-Field Design
#
# **Q8:** Consider, from the tables described in the previous part, the table with the most variables in its functional dependency (or one with fewer that are potentially more interesting).
#
# For all variables associated with that table:
# - Define the _field name_ to be used for each field.
# - List the data type to be used for each field.
# - Indicate whether each field can have a value that is _missing_ (i.e., `NULL`).
# - Write down 3 or 4 example values that you expect each field to have in different rows of the table.

# %% [markdown]
# From the table `edu_level`:
#
# > `State or Territory` - A string variable containing the name of the state/territory. This field won't have a missing value. Example values for this field: New York, California, District of Columbia.
#
# > `Population over the age of 25` - An integer variable containing the population of people over the age of 25 of said state/territory. This field won't have a missing value. Example values for this field: 8730697, 3117186, 8429483
#
# > `With a High School Diploma or higher, Population` - An integer variable containing the population of people having a High School Diploma or higher of said state/territory. This field won't have a missing value. Example values for this field: 2384293, 4372743, 2939402
#
# > `With a High School Diploma or higher, Percentage` - A float variable containing the percentage of people having a High School Diploma or higher of said state/territory. This field won't have a missing value. Example values for this field: 80.43, 95.4, 88.2
#
# > `With a Bachelor's Degree or higher, Population` - An integer variable containing the population of people having a Bachelor's Degree or higher of said state/territory. This field won't have a missing value. Example values for this field: 843943, 129392, 304013
#
# > `With a Bachelor's Degree or higher, Percentage` - A float variable containing the percentage of people having a Bachelor's Degree or higher of said state/territory. This field won't have a missing value. Example values for this field: 50.93, 54.3, 40.6
#
# > `With an Advanced Degree, Population` - An integer variable containing the population of people having an Advanced Degree of said state/territory. This field won't have a missing value. Example values for this field: 184924, 248483, 423842
#
# > `With an Advanced Degree, Percentage` - A float variable containing the percentage of people having an Advanced Degree of said state/territory. This field won't have a missing value. Example values for this field: 30.14, 24.5, 40.1

# %% [markdown]
# **Q9:** Go through your list from the previous question's answer and identify any of the following violations, if present.  If no issues are present, say so instead.
# - A field name that is really a _value_ for a variable.
# - A field that can be derived from other fields.
# - A field whose example values are either a mash-up or a list of values.
# - A set of fields that are different versions of the same thing (e.g., `major1`, `major2`).
# - Any other poor naming or other violations mentioned in Sec. 14.3.

# %% [markdown]
# There are no issues present.

# %% [markdown]
# ---
#
# ---
#
# ## Part C
#
# **Q10:** How much time (in minutes/hours) did you spend on this homework assignment?

# %% [markdown]
# I spent 30 minutes on this assignment.

# %% [markdown]
# **Q11:** Who was your partner for this assignment?  If you worked alone, say so instead.

# %% [markdown]
# I worked alone on this assignment.
